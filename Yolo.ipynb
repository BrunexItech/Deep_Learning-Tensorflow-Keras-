# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip -q install ultralytics
from ultralytics import YOLO

# %%
# !yolo predict model=yolov8n.pt source='/content/Nairobi.jpeg' conf=0.3
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Nairobi.jpeg: 480x640 6 persons, 1 fire hydrant, 577.8ms
# Speed: 23.8ms preprocess, 577.8ms inference, 45.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
import glob
for img in sorted(glob.glob('runs/detect/predict*/**/*.jpg', recursive=True)):
    display(Image(img))
